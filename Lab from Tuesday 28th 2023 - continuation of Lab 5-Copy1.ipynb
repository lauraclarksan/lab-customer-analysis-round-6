# %%
import pandas as pd
import numpy as np

# %%
mca = pd.read_csv("/Users/clark/Desktop/Ironhack/Labs/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv")
mca.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %% [markdown]
# **1. Show the dataframe shape.**

# %%
mca.shape
# Out:
# (10910, 26)

# %% [markdown]
# **2. Standardize header names**

# %%
mca.columns = mca.columns.str.lower().str.replace(" ","_")
mca
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
mca.columns = mca.columns.str.replace("_","")
mca
# Out:
#        unnamed:0 customer       state  customerlifetimevalue response  \
# 0              0  DK49336     Arizona            4809.216960       No
# 1              1  KX64629  California            2228.525238       No
# 2              2  LZ68649  Washington           14947.917300       No
# 3              3  XL78013      Oregon           22332.439460      Yes
# 4              4  QA50777      Oregon            9025.067525       No
# ...          ...      ...         ...                    ...      ...
# 10905      10905  FE99816      Nevada           15563.369440       No
# 10906      10906  KX53892      Oregon            5259.444853       No
# 10907      10907  TL39050     Arizona           23893.304100       No
# 10908      10908  WA60547  California           11971.977650       No
# 10909      10909  IV32877         NaN            6857.519928      NaN
#
#        coverage education effectivetodate employmentstatus gender  ...  \
# ...

# %%
mca.columns = mca.columns.str.replace(":","")
mca
# Out:
#        unnamed0 customer       state  customerlifetimevalue response  \
# 0             0  DK49336     Arizona            4809.216960       No
# 1             1  KX64629  California            2228.525238       No
# 2             2  LZ68649  Washington           14947.917300       No
# 3             3  XL78013      Oregon           22332.439460      Yes
# 4             4  QA50777      Oregon            9025.067525       No
# ...         ...      ...         ...                    ...      ...
# 10905     10905  FE99816      Nevada           15563.369440       No
# 10906     10906  KX53892      Oregon            5259.444853       No
# 10907     10907  TL39050     Arizona           23893.304100       No
# 10908     10908  WA60547  California           11971.977650       No
# 10909     10909  IV32877         NaN            6857.519928      NaN
#
#        coverage education effectivetodate employmentstatus gender  ...  \
# ...

# %% [markdown]
# **3. Which columns are numerical?**

# %%
numerical = mca.select_dtypes("number")
numerical
# Out:
#        unnamed0  customerlifetimevalue  income  monthlypremiumauto  \
# 0             0            4809.216960   48029                  61
# 1             1            2228.525238       0                  64
# 2             2           14947.917300   22139                 100
# 3             3           22332.439460   49078                  97
# 4             4            9025.067525   23675                 117
# ...         ...                    ...     ...                 ...
# 10905     10905           15563.369440       0                 253
# 10906     10906            5259.444853   61146                  65
# 10907     10907           23893.304100   39837                 201
# 10908     10908           11971.977650   64195                 158
# 10909     10909            6857.519928       0                 101
#
#        monthssincelastclaim  monthssincepolicyinception  \
# 0                       7.0                          52
# ...

# %% [markdown]
# **4. Which columns are categorical?**

# %%
categorical = mca.select_dtypes("object")
categorical
# Out:
#       customer       state response  coverage education effectivetodate  \
# 0      DK49336     Arizona       No     Basic   College         2/18/11
# 1      KX64629  California       No     Basic   College         1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor         2/10/11
# 3      XL78013      Oregon      Yes  Extended   College         1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor         1/17/11
# ...        ...         ...      ...       ...       ...             ...
# 10905  FE99816      Nevada       No   Premium  Bachelor         1/19/11
# 10906  KX53892      Oregon       No     Basic   College          1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor          2/6/11
# 10908  WA60547  California       No   Premium   College         2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor          1/8/11
#
#       employmentstatus gender locationcode maritalstatus      policytype  \
# ...

# %% [markdown]
# **5. Check and deal with NaN values**

# %%
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   unnamed0                    10910 non-null  int64
#  1   customer                    10910 non-null  object
#  2   state                       10279 non-null  object
#  3   customerlifetimevalue       10910 non-null  float64
#  4   response                    10279 non-null  object
#  5   coverage                    10910 non-null  object
#  6   education                   10910 non-null  object
#  7   effectivetodate             10910 non-null  object
#  8   employmentstatus            10910 non-null  object
#  9   gender                      10910 non-null  object
#  10  income                      10910 non-null  int64
#  11  locationcode                10910 non-null  object
#  12  maritalstatus               10910 non-null  object
# ...

# %%
mca.isna().sum()
# Out:
# unnamed0                         0
# customer                         0
# state                          631
# customerlifetimevalue            0
# response                       631
# coverage                         0
# education                        0
# effectivetodate                  0
# employmentstatus                 0
# gender                           0
# income                           0
# locationcode                     0
# maritalstatus                    0
# monthlypremiumauto               0
# monthssincelastclaim           633
# monthssincepolicyinception       0
# numberofopencomplaints         633
# numberofpolicies                 0
# policytype                       0
# policy                           0
# renewoffertype                   0
# saleschannel                     0
# totalclaimamount                 0
# vehicleclass                   622
# vehiclesize                    622
# vehicletype                   5482
# dtype: int64

# %% [markdown]
# **Cleaning NaN for the state column**

# %%
mca["state"].value_counts()
# Out:
# state
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: count, dtype: int64

# %%
mca["state"] = mca["gender"].fillna("California")
mca.isna().sum()
# Out:
# unnamed0                         0
# customer                         0
# state                            0
# customerlifetimevalue            0
# response                       631
# coverage                         0
# education                        0
# effectivetodate                  0
# employmentstatus                 0
# gender                           0
# income                           0
# locationcode                     0
# maritalstatus                    0
# monthlypremiumauto               0
# monthssincelastclaim           633
# monthssincepolicyinception       0
# numberofopencomplaints         633
# numberofpolicies                 0
# policytype                       0
# policy                           0
# renewoffertype                   0
# saleschannel                     0
# totalclaimamount                 0
# vehicleclass                   622
# vehiclesize                    622
# vehicletype                   5482
# dtype: int64

# %% [markdown]
# **Cleaning NaN for the response column**

# %%
mca["response"].value_counts()
# Out:
# response
# No     8813
# Yes    1466
# Name: count, dtype: int64

# %%
mca["response"] = mca["response"].fillna("Other")
mca.isna().sum()
# Out:
# unnamed0                         0
# customer                         0
# state                            0
# customerlifetimevalue            0
# response                         0
# coverage                         0
# education                        0
# effectivetodate                  0
# employmentstatus                 0
# gender                           0
# income                           0
# locationcode                     0
# maritalstatus                    0
# monthlypremiumauto               0
# monthssincelastclaim           633
# monthssincepolicyinception       0
# numberofopencomplaints         633
# numberofpolicies                 0
# policytype                       0
# policy                           0
# renewoffertype                   0
# saleschannel                     0
# totalclaimamount                 0
# vehicleclass                   622
# vehiclesize                    622
# vehicletype                   5482
# dtype: int64

# %% [markdown]
# **Cleaning NaN for the monthssincelastclaim column**

# %%
mca["monthssincelastclaim"].value_counts()
# Out:
# monthssincelastclaim
# 3.0     426
# 6.0     394
# 1.0     386
# 7.0     378
# 4.0     373
# 2.0     368
# 5.0     355
# 0.0     354
# 10.0    346
# 16.0    333
# 11.0    331
# 15.0    323
# 13.0    320
# 8.0     315
# 12.0    307
# 17.0    299
# 14.0    299
# 9.0     277
# 23.0    276
# 19.0    276
# 25.0    269
# 21.0    267
# 18.0    257
# 20.0    254
# 22.0    246
# 24.0    237
# 29.0    234
# 28.0    227
# 31.0    221
# 26.0    211
# 27.0    208
# 30.0    201
# 34.0    199
# 33.0    198
# 35.0    157
# 32.0    155
# Name: count, dtype: int64

# %%
col_median = mca["monthssincelastclaim"].dropna().median()
mca["monthssincelastclaim"] = mca["monthssincelastclaim"].fillna(col_median)

# %%
mca.isna().sum()
# Out:
# unnamed0                         0
# customer                         0
# state                            0
# customerlifetimevalue            0
# response                         0
# coverage                         0
# education                        0
# effectivetodate                  0
# employmentstatus                 0
# gender                           0
# income                           0
# locationcode                     0
# maritalstatus                    0
# monthlypremiumauto               0
# monthssincelastclaim             0
# monthssincepolicyinception       0
# numberofopencomplaints         633
# numberofpolicies                 0
# policytype                       0
# policy                           0
# renewoffertype                   0
# saleschannel                     0
# totalclaimamount                 0
# vehicleclass                   622
# vehiclesize                    622
# vehicletype                   5482
# dtype: int64

# %% [markdown]
# **Cleaning NaN for the numberofopencomplaints column**

# %%
mca["numberofopencomplaints"].value_counts()
# Out:
# numberofopencomplaints
# 0.0    8160
# 1.0    1145
# 2.0     414
# 3.0     324
# 4.0     166
# 5.0      68
# Name: count, dtype: int64

# %%
col_median = mca["numberofopencomplaints"].dropna().median()
mca["numberofopencomplaints"] = mca["numberofopencomplaints"].fillna(col_median)

# %%
mca.isna().sum()
# Out:
# unnamed0                         0
# customer                         0
# state                            0
# customerlifetimevalue            0
# response                         0
# coverage                         0
# education                        0
# effectivetodate                  0
# employmentstatus                 0
# gender                           0
# income                           0
# locationcode                     0
# maritalstatus                    0
# monthlypremiumauto               0
# monthssincelastclaim             0
# monthssincepolicyinception       0
# numberofopencomplaints           0
# numberofpolicies                 0
# policytype                       0
# policy                           0
# renewoffertype                   0
# saleschannel                     0
# totalclaimamount                 0
# vehicleclass                   622
# vehiclesize                    622
# vehicletype                   5482
# dtype: int64

# %% [markdown]
# **Cleaning NaN for the vehicleclass column**

# %%
mca["vehicleclass"].value_counts()
# Out:
# vehicleclass
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: count, dtype: int64

# %%
mca["vehicleclass"] = mca["vehicleclass"].fillna("Four-Door Car")
mca.isna().sum()
# Out:
# unnamed0                         0
# customer                         0
# state                            0
# customerlifetimevalue            0
# response                         0
# coverage                         0
# education                        0
# effectivetodate                  0
# employmentstatus                 0
# gender                           0
# income                           0
# locationcode                     0
# maritalstatus                    0
# monthlypremiumauto               0
# monthssincelastclaim             0
# monthssincepolicyinception       0
# numberofopencomplaints           0
# numberofpolicies                 0
# policytype                       0
# policy                           0
# renewoffertype                   0
# saleschannel                     0
# totalclaimamount                 0
# vehicleclass                     0
# vehiclesize                    622
# vehicletype                   5482
# dtype: int64

# %% [markdown]
# **Cleaning NaN for the vehiclesize column**

# %%
mca["vehiclesize"].value_counts()
# Out:
# vehiclesize
# Medsize    7251
# Small      1966
# Large      1071
# Name: count, dtype: int64

# %%
mca["vehiclesize"] = mca["vehiclesize"].fillna("Other")
mca.isna().sum()
# Out:
# unnamed0                         0
# customer                         0
# state                            0
# customerlifetimevalue            0
# response                         0
# coverage                         0
# education                        0
# effectivetodate                  0
# employmentstatus                 0
# gender                           0
# income                           0
# locationcode                     0
# maritalstatus                    0
# monthlypremiumauto               0
# monthssincelastclaim             0
# monthssincepolicyinception       0
# numberofopencomplaints           0
# numberofpolicies                 0
# policytype                       0
# policy                           0
# renewoffertype                   0
# saleschannel                     0
# totalclaimamount                 0
# vehicleclass                     0
# vehiclesize                      0
# vehicletype                   5482
# dtype: int64

# %% [markdown]
# **Cleaning NaN for the vehicletype column**

# %%
mca["vehicletype"].value_counts()
# Out:
# vehicletype
# A    5428
# Name: count, dtype: int64

# %%
mca["vehicletype"] = mca["vehicletype"].fillna("Other")
mca.isna().sum()
# Out:
# unnamed0                      0
# customer                      0
# state                         0
# customerlifetimevalue         0
# response                      0
# coverage                      0
# education                     0
# effectivetodate               0
# employmentstatus              0
# gender                        0
# income                        0
# locationcode                  0
# maritalstatus                 0
# monthlypremiumauto            0
# monthssincelastclaim          0
# monthssincepolicyinception    0
# numberofopencomplaints        0
# numberofpolicies              0
# policytype                    0
# policy                        0
# renewoffertype                0
# saleschannel                  0
# totalclaimamount              0
# vehicleclass                  0
# vehiclesize                   0
# vehicletype                   0
# dtype: int64

# %% [markdown]
# **6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February**

# %%
mca["effectivetodate"]
# Out:
# 0        2/18/11
# 1        1/18/11
# 2        2/10/11
# 3        1/11/11
# 4        1/17/11
#           ...
# 10905    1/19/11
# 10906     1/6/11
# 10907     2/6/11
# 10908    2/13/11
# 10909     1/8/11
# Name: effectivetodate, Length: 10910, dtype: object

# %%
mca["effectivetodate"] = pd.to_datetime(mca["effectivetodate"], format = "%m-%d-%Y")

# %%
mca["month"] = mca["effectivetodate"].dt.month

# %%
firstquarter = mca[mca["month"].isin([1,2])]
mca
# Out:
#        unnamed0 customer state  customerlifetimevalue response  coverage  \
# 0             0  DK49336     M            4809.216960       No     Basic
# 1             1  KX64629     F            2228.525238       No     Basic
# 2             2  LZ68649     M           14947.917300       No     Basic
# 3             3  XL78013     M           22332.439460      Yes  Extended
# 4             4  QA50777     F            9025.067525       No   Premium
# ...         ...      ...   ...                    ...      ...       ...
# 10905     10905  FE99816     F           15563.369440       No   Premium
# 10906     10906  KX53892     F            5259.444853       No     Basic
# 10907     10907  TL39050     F           23893.304100       No  Extended
# 10908     10908  WA60547     F           11971.977650       No   Premium
# 10909     10909  IV32877     M            6857.519928    Other     Basic
#
#       education effectivetodate employmentstatus gender  ...  \
# ...

# %% [markdown]
# # **Lab 3**
#
# **1. Show DataFrame info**

# %%
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
pd.set_option('display.max_columns', None)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
mca
# Out:
#        unnamed0 customer state  customerlifetimevalue response  coverage  \
# 0             0  DK49336     M            4809.216960       No     Basic
# 1             1  KX64629     F            2228.525238       No     Basic
# 2             2  LZ68649     M           14947.917300       No     Basic
# 3             3  XL78013     M           22332.439460      Yes  Extended
# 4             4  QA50777     F            9025.067525       No   Premium
# ...         ...      ...   ...                    ...      ...       ...
# 10905     10905  FE99816     F           15563.369440       No   Premium
# 10906     10906  KX53892     F            5259.444853       No     Basic
# 10907     10907  TL39050     F           23893.304100       No  Extended
# 10908     10908  WA60547     F           11971.977650       No   Premium
# 10909     10909  IV32877     M            6857.519928    Other     Basic
#
#       education effectivetodate employmentstatus gender  income locationcode  \
# ...

# %%
mca = mca.drop("unnamed0", axis=1)
mca
# Out:
#       customer state  customerlifetimevalue response  coverage education  \
# 0      DK49336     M            4809.216960       No     Basic   College
# 1      KX64629     F            2228.525238       No     Basic   College
# 2      LZ68649     M           14947.917300       No     Basic  Bachelor
# 3      XL78013     M           22332.439460      Yes  Extended   College
# 4      QA50777     F            9025.067525       No   Premium  Bachelor
# ...        ...   ...                    ...      ...       ...       ...
# 10905  FE99816     F           15563.369440       No   Premium  Bachelor
# 10906  KX53892     F            5259.444853       No     Basic   College
# 10907  TL39050     F           23893.304100       No  Extended  Bachelor
# 10908  WA60547     F           11971.977650       No   Premium   College
# 10909  IV32877     M            6857.519928    Other     Basic  Bachelor
#
#       effectivetodate employmentstatus gender  income locationcode  \
# ...

# %% [markdown]
# **2. Describe DataFrame**

# %%
mca.describe()
# Out:
#        customerlifetimevalue        income  monthlypremiumauto  \
# count           10910.000000  10910.000000        10910.000000
# mean             8018.241094  37536.284785           93.196059
# std              6885.081434  30359.195670           34.442532
# min              1898.007675      0.000000           61.000000
# 25%              4014.453113      0.000000           68.000000
# 50%              5771.147235  33813.500000           83.000000
# 75%              8992.779137  62250.750000          109.000000
# max             83325.381190  99981.000000          298.000000
#
#        monthssincelastclaim  monthssincepolicyinception  \
# count          10910.000000                10910.000000
# mean              15.082401                   48.091934
# std                9.787208                   27.940675
# min                0.000000                    0.000000
# 25%                7.000000                   24.000000
# 50%               14.000000                   48.000000
# ...

# %% [markdown]
# **3. Show a plot of the total number of responses**

# %%
sns.countplot(x="response", data=mca)
# Out:
# <Axes: xlabel='response', ylabel='count'>

# %% [markdown]
# **4. Show a plot of the response rate by the sales channel**

# %%
sns.countplot(x="response", hue="saleschannel", data=mca)
# Out:
# <Axes: xlabel='response', ylabel='count'>

# %% [markdown]
# **5. Show a plot of the response rate by the total claim amount**

# %%
sns.barplot(x="response", y="totalclaimamount", data=mca)
# Out:
# <Axes: xlabel='response', ylabel='totalclaimamount'>

# %% [markdown]
# **6. Show a plot of the response rate by income**

# %%
sns.barplot(x="response", y="income", data=mca)
# Out:
# <Axes: xlabel='response', ylabel='income'>

# %% [markdown]
# # **Lab 5**
#
# **1. Processing Data**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, Normalizer, StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

# %%
mca
# Out:
#       customer state  customerlifetimevalue response  coverage education  \
# 0      DK49336     M            4809.216960       No     Basic   College
# 1      KX64629     F            2228.525238       No     Basic   College
# 2      LZ68649     M           14947.917300       No     Basic  Bachelor
# 3      XL78013     M           22332.439460      Yes  Extended   College
# 4      QA50777     F            9025.067525       No   Premium  Bachelor
# ...        ...   ...                    ...      ...       ...       ...
# 10905  FE99816     F           15563.369440       No   Premium  Bachelor
# 10906  KX53892     F            5259.444853       No     Basic   College
# 10907  TL39050     F           23893.304100       No  Extended  Bachelor
# 10908  WA60547     F           11971.977650       No   Premium   College
# 10909  IV32877     M            6857.519928    Other     Basic  Bachelor
#
#       effectivetodate employmentstatus gender  income locationcode  \
# ...

# %% [markdown]
# **X-y split**

# %%
X = mca.drop(["customer","totalclaimamount"], axis=1)
y = mca["totalclaimamount"]

# %% [markdown]
# **Train-test-split**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
y_train
# Out:
# 7722     59.861963
# 6888    340.453606
# 675     250.423844
# 4098    499.200000
# 4518     52.435202
#            ...
# 5734    777.600000
# 5191    470.400000
# 5390    331.200000
# 860     336.000000
# 7270    552.000000
# Name: totalclaimamount, Length: 7637, dtype: float64

# %% [markdown]
# **Normalize (numerical)**

# %%
numerical = X.select_dtypes(include=['int64', 'float64']).columns

# %%
scaler = StandardScaler()

# %%
X_train[numerical] = scaler.fit_transform(X_train[numerical])
X_test[numerical] = scaler.transform(X_test[numerical])

# %% [markdown]
# # **Lab 6**
#
# **1. Processing Data**

# %% [markdown]
# **One Hot/Label Encoding (categorical)**

# %%
categorical = X_train.select_dtypes(include=['object']).columns

# %%
X_train = pd.get_dummies(X_train, columns=categorical, drop_first=True)
X_test = pd.get_dummies(X_test, columns=categorical, drop_first=True)

# %% [markdown]
# **Concat DataFrames**

# %%
X_all = pd.concat([X_train, X_test], axis=0)
y_all = pd.concat([y_train, y_test], axis=0)

# %% [markdown]
# **2. Linear Regression**
#
# **Apply linear regression**

# %%
lm = LinearRegression()

# %%
lm.fit(X_train[numerical],y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **3. Model Validation**
#
# **Description:
# R2
# MSE
# RMSE
# MAE**

# %%
predictions = lm.predict(X_test[numerical])

# %%
rmse = mean_squared_error(y_test, predictions, squared=False)
mse = mean_squared_error(y_test, predictions, squared=True)
mae = mean_absolute_error(y_test, predictions)
print("R2_score:", round(r2_score(y_test, predictions), 2))
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# R2_score: 0.52
# RMSE: 199.4909803333445
# MAE: 144.81589028934388
